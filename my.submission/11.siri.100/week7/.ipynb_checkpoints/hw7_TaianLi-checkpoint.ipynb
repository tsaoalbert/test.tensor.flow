# %% [markdown]
# <h1> HW #7:  Tree and Tree Algorithms </h1>

# %% [markdown]
# <h3> The questions are taken from
# <a href='
# http://interactivepython.org/runestone/static/pythonds/Graphs/ProgrammingExercises.html
#          '> 7.26. Programming Exercises  </a></h3>

# %% [raw]
# Q#1 Modify the depth first search function to produce a topological sort. Write down the algorithms with pseudo codes. No coding is required

# %% [raw]
# function topologicalSort(graph):
#     initiate a depth first search graph
#     fill the DFSgraph with a graph that need to be create a topological sort
#     initiate a list that is used to contain the sorted result
#     for each vertex in DFSgraph:
#         for each next vertex in DFSgraph:
#             if the finish time of the next vertex is larger
#                 then set next vertex as the largest vertex
#         delete the largest vertex from the DFSgraph and append it in the list
#     return the list with the topological sort.

# %% [raw]
# Q#2 Modify the depth first search to produce strongly connected components. Write down the algorithms with pseudo codes. No coding is required

# %% [raw]
# function generateStronglyConnectedComponents(graph):
#     initiate a depth first search graph
#     fill the DFSgraph with a graph that need to be create the strongly connected components
#     create a graph by coping all the vertexs deeply in the previous DFSgraph but not their edge(connectedTo)
#     create edges of vertexs in the new graph by reversing the from vertex and the to vertex one by one through edges recorded in the vertexs of the parameter graph to get the graph transposed
#     create a topological sort from the DFSgraph(as the previous function I created for the last question)
#     create a new DFSgraph from the topological sort, return a tree(strongly connected components) or output its vertex after each the main loop finish.

# %% [raw]
# Q#3: (Optional) Write a Python program to implement the transpose method for the Graph class.

# %%
import sys, copy


class Vertex:
    def __init__(self,key):
        self.id = key
        self.connectedTo = {}
        self.color = 'white'
        self.dist = sys.maxsize
        self.pred = None
        self.disc = 0    # discover time
        self.fin = 0     # finish   time

    
    def addNeighbor(self,nbr,weight=0):
        self.connectedTo[nbr] = weight

    def setColor(self,color):
        self.color = color

    def setDistance(self,d):
        self.dist = d

    def setPred(self,p):
        self.pred = p

    def setDiscovery(self,dtime):
        self.disc = dtime
        
    def setFinish(self,ftime):
        self.fin = ftime
        
    def getFinish(self):
        return self.fin
        
    def getDiscovery(self):
        return self.disc
        
    def getPred(self):
        return self.pred
        
    def getDistance(self):
        return self.dist
        
    def getColor(self):
        return self.color

    def getConnections(self):
        return self.connectedTo.keys()

    def getWeight(self,nbr):
        return self.connectedTo[nbr]

        return self.connectedTo.get(nbr,0)

    def __str__(self):
        return str(self.id) + ' connected to: ' + str([x.id for x in self.connectedTo])

    def getId(self):
        return self.id


class Graph:
    def __init__(self):
        self.vertList = {}
        self.numVertices = 0

    def __len__(self):
        return   self.numVertices
    
    def addVertex(self,key):
        self.numVertices = self.numVertices + 1
        newVertex = Vertex(key)
        self.vertList[key] = newVertex
        return newVertex


    def getVertex(self,n):
        if n in self.vertList:
            return self.vertList[n]
        else:
            return None

    def __getitem__ (self,n):
        return self.getVertex(n)
        
    def __contains__(self,n):
        return n in self.vertList

    def addEdge(self,f,t,cost=-1):
        if f not in self.vertList:
            nv = self.addVertex(f)
        if t not in self.vertList:
            nv = self.addVertex(t)
        self.vertList[f].addNeighbor(self.vertList[t], cost)

    def getVertices(self):
        return self.vertList.keys()

    def __iter__(self):
        return iter(self.vertList.values())

    def __str__(self):
        s = "Graph:\n"
        for i in self.vertList:
            s += str( self.vertList[i] )  +"\n"
        return s



def generateTransposedGraph(graph):
    transposedGraph = Graph()
    transposedGraph.vertList = copy.deepcopy(graph.vertList)
    transposedGraph.numVertices = graph.numVertices
    for vk in transposedGraph.vertList:
        transposedGraph[vk].connectedTo.clear()
    for vk2 in graph.vertList.keys():
        for toVertex in graph.vertList[vk2].getConnections():
            transposedGraph.addEdge(toVertex.id,vk2)
    return transposedGraph


g = Graph()
g.addEdge(2,1)
g.addEdge(2,4)
g.addEdge(1,4)
g.addEdge(4,3)
g.addEdge(2,5)
for v in g.vertList:
    print(g.vertList[v])

gt = generateTransposedGraph(g)
print("----------------")
for v2 in gt.vertList:
    print(gt.vertList[v2])
# Out:
# 2 connected to: [1, 4, 5]
# 1 connected to: [4]
# 4 connected to: [3]
# 3 connected to: []
# 5 connected to: []
# ----------------
# 2 connected to: []
# 1 connected to: [2]
# 4 connected to: [2, 1]
# 3 connected to: [4]
# 5 connected to: [2]

# %% [raw]
# Q#4: Using BFS revise the maze program from the recursion chapter to find the shortest path out of a maze.

# %%
import sys


class Vertex:
    def __init__(self,key):
        self.id = key
        self.connectedTo = {}
        self.color = 'white'
        self.dist = sys.maxsize
        self.pred = None
        self.disc = 0    # discover time
        self.fin = 0     # finish   time

    
    def addNeighbor(self,nbr,weight=0):
        self.connectedTo[nbr] = weight

    def setColor(self,color):
        self.color = color

    def setDistance(self,d):
        self.dist = d

    def setPred(self,p):
        self.pred = p

    def setDiscovery(self,dtime):
        self.disc = dtime
        
    def setFinish(self,ftime):
        self.fin = ftime
        
    def getFinish(self):
        return self.fin
        
    def getDiscovery(self):
        return self.disc
        
    def getPred(self):
        return self.pred
        
    def getDistance(self):
        return self.dist
        
    def getColor(self):
        return self.color

    def getConnections(self):
        return self.connectedTo.keys()

    def getWeight(self,nbr):
        return self.connectedTo[nbr]

        return self.connectedTo.get(nbr,0)

    def __str__(self):
        return str(self.id) + ' connected to: ' + str([x.id for x in self.connectedTo])

    def getId(self):
        return self.id


class Graph:
    def __init__(self):
        self.vertList = {}
        self.numVertices = 0

    def __len__(self):
        return   self.numVertices
    
    def addVertex(self,key):
        self.numVertices = self.numVertices + 1
        newVertex = Vertex(key)
        self.vertList[key] = newVertex
        return newVertex


    def getVertex(self,n):
        if n in self.vertList:
            return self.vertList[n]
        else:
            return None

    def __getitem__ (self,n):
        return self.getVertex(n)
        
    def __contains__(self,n):
        return n in self.vertList

    def addEdge(self,f,t,cost=-1):
        if f not in self.vertList:
            nv = self.addVertex(f)
        if t not in self.vertList:
            nv = self.addVertex(t)
        self.vertList[f].addNeighbor(self.vertList[t], cost)

    def getVertices(self):
        return self.vertList.keys()

    def __iter__(self):
        return iter(self.vertList.values())

    def __str__(self):
        s = "Graph:\n"
        for i in self.vertList:
            s += str( self.vertList[i] )  +"\n"
        return s


class Queue:
    def __init__(self):
        self.items = []

    def isEmpty(self):
        return self.items == []
    
    def enqueue(self, item):
        self.items.insert(0,item)

    def dequeue(self):
        return self.items.pop()

    def size(self):
        return len(self.items)

def bfs(start):
  start.setDistance(0)
  start.setPred(None)
  vertQueue = Queue()   # use queue
  vertQueue.enqueue(start)
  while (vertQueue.size() > 0):
    currentVert = vertQueue.dequeue()
    for nbr in currentVert.getConnections():
      if (nbr.getColor() == 'white'):
        nbr.setColor('gray')
        nbr.setDistance(currentVert.getDistance() + 1)
        nbr.setPred(currentVert)
        vertQueue.enqueue(nbr)
    currentVert.setColor('black')


def traverse(y):
    x = y
    print ("Backtrace Node", end=" ")
    while (x.getPred()):
        i = x.getId()
        y = x
        x = x.getPred()
        w = x.getWeight( y )
        s = str(i) + " (" + str(w) + ")"
        print( s, end="-->")

    print(x.getId())


def buildGraph(blockList):
    g = Graph()
    for key in range(1,81):
        if key not in blockList:
            if ((key % 10) != 0) and ((key+1) not in blockList):
                g.addEdge(key,key+1)
            if (key < 71) and ((key+10) not in blockList):
                g.addEdge(key,key+10)
            if (key > 10) and ((key-10) not in blockList):
                g.addEdge(key, key-10)
            if ((key % 10) != 1) and ((key-1) not in blockList):
                g.addEdge(key, key-1)   
    return g
g = buildGraph ([12,13,14,17,18,19,24,34,28,38,48])
#print (g)
w0 = 21
w1 = 29
bfs( g[w0])
traverse(g[w1])
# Out:
# Backtrace Node 29 (-1)-->39 (-1)-->49 (-1)-->59 (-1)-->58 (-1)-->57 (-1)-->47 (-1)-->46 (-1)-->45 (-1)-->44 (-1)-->43 (-1)-->33 (-1)-->23 (-1)-->22 (-1)-->21

# %% [raw]
# Q#5:
# Dijkstra’s Algorithm: Fill in the table, where
# dv = Shortest path length from source node s to v
# pv = Node in T to which Node v is connected

# %% [markdown]
# <div class="binarySearch">
#     <div style="float:left;margin-top:75px;">
#     <figure>
#         <img src="images/dijkstra.hw7.5.png" height="400" width="500"  />
#         <figcaption style="text-align:center;">   </figcaption>
#     </figure>
#     </div>
#     <div style="float:left;margin-right:55px;">
#     <figure>
#         <img src="images/dijkstra.hw7.5_2.png" width="300"   />
#         <figcaption style="text-align:center;">   </figcaption>
#     </figure>
#     </div>
# </div>

# %% [raw]
#     K dv pv
# A   T  0  -
# B   T  8  A
# C   T 13  B
# D   T 14  C
# E   T 12  F
# F   T 10  A

# %% [markdown]
# Q#6
# What is the Big-O running time of
# * the buildGraph function?
# * the topological sort algorithm.
# * the strongly connected components algorithm.
# * Prim’s minimum spanning tree algorithm?

# %% [raw]
# Answer:
#     buildGraph function = O(n*n)
#     my topological sort algorithm = O(n*n)
#     my strongly connected components algorithm = O(n*n)
#     Prim's minimum spanning tree algorithm = O(n)
