# %% [markdown]
# <h1> Assignments #3:  <a href='http://interactivepython.org/runestone/static/pythonds/BasicDS/toctree.html'>
# Basic Data Structures </a> </h1>

# %% [markdown]
# <h3> <a href='
# http://interactivepython.org/runestone/static/pythonds/BasicDS/ProgrammingExercises.html
# '>   Programming Exercises  </a> </h3>

# %% [markdown]
# * 3.1 (10%) Modify the infix-to-postfix algorithm so that it can handle errors.
# * 3.2 (10%) Modify the postfix evaluation algorithm so that it can handle errors.
# * 3.3 (10%) Implement a direct infix evaluator that combines both infix-to-postfix conversion
# * 3.4 (10%) Turn your direct infix evaluator from the previous problem into a calculator that can handles arithmetic operators +,-,*,/, //, %, ** and parenthesis.

# %%
#Ans 3.1
class Stack:
    def __init__(self):
        self.items = []

    def isEmpty(self):
        return self.items == []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        return self.items.pop()

    def peek(self):
        return self.items[len(self.items)-1]

    def size(self):
        return len(self.items)


def infixToPostfix(infixexpr):
    prec = {}
    prec["*"] = 3
    prec["/"] = 3
    prec["+"] = 2
    prec["-"] = 2
    prec["("] = 1
    opStack = Stack()
    postfixList = []
    tokenList = infixexpr.split()

    for token in tokenList:
        if token in "ABCDEFGHIJKLMNOPQRSTUVWXYZ" or token in "0123456789":
            postfixList.append(token)
        elif token == '(':
            opStack.push(token)
        elif token == ')':
            topToken = opStack.pop()
            while topToken != '(':
                postfixList.append(topToken)
                topToken = opStack.pop()
        else:
            while (not opStack.isEmpty()) and (prec[opStack.peek()] >= prec[token]):
                postfixList.append(opStack.pop())
            opStack.push(token)

    while not opStack.isEmpty():
        postfixList.append(opStack.pop())
    return " ".join(postfixList)

print(infixToPostfix("A * B + C * D"))
print(infixToPostfix("( A + B ) * C - ( D - E ) * ( F + G )"))

print(infixToPostfix("( A + B ) * ( C + D )"))
print(infixToPostfix("( A + B ) * C"))
print(infixToPostfix("A + B * C"))
# Out:
# A B * C D * +
# A B + C * D E - F G + * -
# A B + C D + *
# A B + C *
# A B C * +

# %%
#Ans 3.2
# This function evalutes the postfix expressions and returns

# evaluated value if expression is valid otherwise returns error message

def postfixEval(postfixExpr):

    stack = []

    tokenList = postfixExpr. split()

    for token in tokenList:

        if token in "0123456789":

            stack.append(int(token))

        elif (len(stack) < 2):
            return "Error!"

# Checking that if there is an operand missing in expression.

# If operator token is encountered, stack must have atleast

# two operands otherwise it is an error.

# len() function returns size of the stack().

       

    operand2 = stack.pop()

    operand1 = stack.pop()

    result = doMath(token,operand1, operand2)

    stack.append(result)

# Checking operator missing case, if stack size is 1, then

# given postfix expression is valid, otherwise expression is invalid.

    if (len(stack) == 1):

        return stack.pop()

# Operator is missed in postfix expression, hence returning error

        return "Error!"

def doMath(op,op1,op2):

    if op == "*":

        return op1 * op2

    elif op == "/":

        return op1 / op2

    elif op == "+":

        return op1 + op2

    else:

        return op1 - op2

instr = input('enter a postfix expression : ')

print (postfixEval(instr))
# Out:
# enter a postfix expression : 2 6 *
# 12

# %%
#Ans 3.3
#from InfixToPostfix import infixToPostfix
#from InfixToPostfix import readInput
#from PostfixEval import postfixEvaluator


def infixCalc(infixExpr):
    postfix = infixToPostfix(infixExpr)
    print ("Postfix: ", postfix)
    ans = postfixEvaluator(postfix)
    return ans


def main():
    infixExpr = readInput()
    ans = infixCalc(infixExpr)
    print ("Result: ", ans)


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-22a9298125f5> in <module>
#      19
#      20 if __name__ == '__main__':
# ---> 21     main()
#
# <ipython-input-3-22a9298125f5> in main()
#      13
#      14 def main():
# ---> 15     infixExpr = readInput()
#      16     ans = infixCalc(infixExpr)
#      17     print ("Result: ", ans)
#
# NameError: name 'readInput' is not defined

# %% [markdown]
# * 3.12 (10%) Extend the program from Listing 2.15 to handle palindromes with spaces. For example, I PREFER PI is a palindrome that reads the same forward and backward if you ignore the blank characters.

# %%
#Ans 3.12
#from pythonds.basic.deque import Deque
import string

class Deque:                            # Deque implementation based on python list
    def __init__(self):
        self.items = []

    def isEmpty(self):
        return self.items == []
    # O(N)                              # Equivalent Python deque methods
    def addFront(self, item):           # appendLeft
        self.items.insert(0,item)

    # O(1)
    def addRear(self, item):            # append
        self.items.append(item)
    # O(N)
    def removeFront(self):              # popLeft
        return self.items.pop(0)
    # O(1)
    def removeRear(self):               # pop
        return self.items.pop()

    def size(self):
        return len(self.items)
    
def palchecker(aString):
    aString = ''.join(e for e in aString if e.isalpha())
    aString = aString.upper()
    chardeque = Deque()

    for ch in aString:
        chardeque.addRear(ch)

    stillEqual = True

    while chardeque.size() > 1 and stillEqual:
        first = chardeque.removeFront()
        last = chardeque.removeRear()
        if first != last:
            stillEqual = False

    return stillEqual
A = [ "A Nut for a Jar of Tuna", "A But Tuba", "As I Pee, Sir, I See Pisa", \
        "A Toyota's a Toyota", "No X in Nixon", "radar",  "I prefer pi", "Race car" ] 
for s in A:
    assert palchecker (s)
assert not (palchecker("lsdkjfskf"))

# %% [markdown]
# (30%) Modify the unorderedList class as follows:
# * allow duplicates
# * remove method can work correctly on non-existing items
# * Improve the time of length method to O(1)
# * Implement __str__ method so that unorderedList are displayed the Python way
# * Implement the remaining operations defined in the UnorderedList ADT (append, index, pop, insert).

# %%
class Node:
    def __init__(self,initdata):
        self.data = initdata
        self.next = None

    def getData(self):
        return self.data

    def __str__(self):
        return str(self.data)

    def getNext(self):
        return self.next

    def setData(self,newdata):
        self.data = newdata

    def setNext(self,newnext):
        self.next = newnext


class List() :
    def __init__(self, L=[]):
        self.count = 0     # to speed up len() method
        self.head = None
        for x in L:
            self.append (x)
            
    def __len__(self): 
        return self.count
    
    def isEmpty(self):
        return self.head == None
        
    def getitem(self,i): #  helper function for index
        j = 0 
        current = self.head
        n = len(self)
        while i<0:
            i += n
        previous = None
        while current != None and j < i :
            previous = current
            current = current.getNext()
            j += 1            
        if ( current==None):
          return None, previous, current
        else:
          return current.getData(), previous, current
 
    def __getitem__(self,i): # index
        x,y,z = self.getitem (i)
        return x

    def searchHelper (self,item): # does not remove the duplicate of the item
        current = self.head
        previous = None
        found = False
        while current!=None and not found:
            if current.getData() == item:
                found = True
            else:
                previous = current
                current = current.getNext()
        return found, previous, current 

    def search (self,item): # does not remove the duplicate of the item
        x,y,z = self.searchHelper (item)
        return x
    
    def list (self):
        ans = []
        current = self.head
        while current != None:
            ans.append( current.getData() )
            current = current.getNext()
        return  ans       
        
    def __str__(self):
        return str ( self.list ())

    # push front, time O(1)
    def add(self,item):            # add at the list head
        self.count += 1
        temp = Node( item )
        if self.head !=None:
            temp.setNext ( self.head)
        self.head = temp
        return temp
            
    def pushFront(self,item):      # add at the list head, O(1)
        self.count += 1
        temp = Node( item )
        if self.head !=None:
            temp.setNext ( self.head)
        self.head = temp
        return temp
    
    # with tail pointer, append() can take time O(1) only
    def append( self, item ):  # xxx add a new item to the end of the list 
        return self.insert ( self.count, item)

            
    def insert(self, pos,item): 
        x,previous, current = self.getitem (pos)

        if ( pos > len(self)):
            print ( "fail to add ", item, "at", pos)
            return None
        else:
            temp = Node(item)
            self.count += 1
            temp.setNext(current)
            if previous==None:
                self.head = temp
            else:
                previous.setNext(temp)
            return temp

           
    def erase (self, previous, current, found, item):
    # xxx consider the self.tail pointer
        if found:
          self.count -= 1
          if previous == None:
            self.head = current.getNext()  # remove a node at the head
          else:
            previous.setNext(current.getNext())
          return current.getData()
        else:
          print ( "Cannot remove",  item )
          return None
        
    def pop(self, i ): # removes and returns the last item in the list.
        j = 0 
        previous = None
        current = self.head
        n = len(self)
        while i < 0:
            i += n
        while current != None and j < i :
            previous = current
            current = current.getNext()
            j += 1
        found = current != None and j==i  
        return self.erase (previous, current, found, "")

    #  take time O(1)
    def popFront(self): # 
        if self.head!=None:
            x = self.head.getData();
            self.head = self.head.getNext()
            return x
        else:
          print ( "Cannot remove",  item )
          return None
        
    def remove(self,item): # does not remove the duplicate of the item
        found, previous, current = self.searchHelper (item )
        return self.erase (previous, current, found, item)

# %%
def test1():
    L = [ 31,77, 17, 93, 26, 54 ]
    A = List(   )
    B = List()
    C = List()

    for x in L:
        A.add (x)
        B.append (x)
        C.insert (0,x)
    print (A,B)
    assert A.list() == L[::-1]  
    assert B.list() == L  
    for x in L:
        A.pop (0)
        B.pop (-1)
        C.remove(x)
    assert (A.isEmpty())
    print (A,B,C)

test1()
# Out:
# [54, 26, 93, 17, 77, 31] [31, 77, 17, 93, 26, 54]
# [] [] []

# %% [markdown]
# (10%) Explain how a singly linked list with both head  tail pointer can be used to implement a queue that would have an average performance of O(1) for enqueue and dequeue operations.(No coding)

# %%
#QueueLinkedList has implementation with front and back pointers which keep track of the head and
#tail of the queue - this helps in implementing Enqueu and Dequeue operations in O(1).

For the singly linked list L with tail pointer, both the operation L.pop(O) and L.append() take O(1).
When we use L to implement Queue, the enqueue() method can be implemented with L.append(), and dequeue 
with L.pop(O)

# %% [markdown]
# (10%) Use doubly linked lists to implement queue, stack, and deque that would have have an average performance of O(1)  for operations of adding or removing operations. Hints: implement deque first, then you can build stack and queue on top of deque

# %%
#Ans doubly linked lists to implement queue, stack, and deque 
class Node:
    def __init__(self,initdata):
        self.data = initdata
        self.next = self.previous = None

    def getData(self):
        return self.data

    def __str__(self):
        return str(self.data)

    def getNext(self):
        return self.next
    
    def getPrevious(self):
        return self.previous
    
    def setData(self,newdata):
        self.data = newdata

    def setNext(self,newnext):
        self.next = newnext
        
    def setPrevious (self, p):
        self.previous = p
        
        
class doublyLinkedList:

    def __init__(self):
        self.count = 0
        self.head = None

    def isEmpty(self):
        return self.count == 0
            
    def insert (self,item, curr ):      # xxx add at the list head
        self.count += 1
        temp = Node(item)
        if self.head ==None:
            temp.setNext( temp )
            temp.setPrevious (temp)
            self.head = temp
        else:
            prev  = curr.getPrevious ()
            temp.setNext( curr )
            temp.setPrevious ( prev )
            curr.setPrevious ( temp )
            prev.setNext ( temp )
        return temp
    
    def addFront (self, item):
        self.head = self.insert ( item, self.head )
        
    def add (self,item):
        self.head = self.insert ( item, self.head )

    def addRear (self, item):
        self.insert ( item, self.head )
        

    def __getitem__(self,i):    # xxx index
        cnt = 0 
        current = self.head
        while current != None and cnt < i :
            current = current.getNext()
            cnt += 1
        if ( current==None):
          return None
        else:
          return current.getData()
 
    def toList (self):                  # convert to Pylist list
        ans = []
        curr = self.head
        while curr != None:
            ans.append( curr.getData() )
            curr = curr.getNext()
            if curr==self.head:
                break;
        return  ans
    
    def __str__(self):
        return str ( self.toList() )
        
    def length(self): 
        return self.count

    def find (self,item):
        curr = self.head
        found = False
        while curr != None:
            if curr.getData() == item:
                return curr
            curr = curr.getNext()
            if curr==self.head:
                break;
        return None 
    
    def search(self,item):
        return self.find ( item ) != None

    def remove (self,item):
        curr = self.find ( item ) 
        if curr == None:
            print ( "Cannot remove %d" % (item) )
            return None
        else:
            return self.removeNode  ( curr )
        
    def removeNode (self,curr ):    
        self.count -= 1
        if self.count==0:
            self.head = None
        prev = curr.getPrevious()
        next = curr.getNext()
        prev.setNext( next )
        next.setPrevious( prev )
        if curr == self.head :
            self.head = next
        return curr.getData()
            
    def removeFront ( self):
        x = self.head
        if x != None:
            x = self.removeNode ( x )
        return x

    def removeRear ( self):
        x = self.head
        if x != None:
            x = x.getPrevious()
            x = self.removeNode ( x )
        return x

def testDoublyLinkedList (n):          
    mylist = doublyLinkedList()
    for i in range (n):
        mylist.add(i)
    for i in range (n+1):
        mylist.remove (i)
    return  mylist.length() 


def testDoublyLinkedList2 (): 
    mylist = doublyLinkedList()
    for i in [31,77,17,93,26,54]:
        mylist.add(i)

    assert mylist.toList() == ([54, 26, 93, 17, 77, 31])  
    assert mylist.length() ==6 
    assert mylist.search(93)
    assert not mylist.search(100)

    mylist.add(100)
    assert mylist.search(93)

    mylist.remove(54)  
    mylist.remove(93)
    mylist.remove(31)
    mylist.remove(93)
    assert str(mylist)==str ([100, 26, 17, 77]) 
    assert not mylist.search(93)
        
def testDoublyLinkedList3 (): 
    mylist = doublyLinkedList()
    for i in [31,77,17,93,26,54]:
        mylist.addFront(i)
    mylist.removeFront ( )
    mylist.removeRear()
    assert mylist.toList()==[26, 93, 17, 77]  
    assert mylist.search(93)
    mylist.removeFront ( )
    mylist.removeRear()
    assert mylist.toList() == [93, 17]
    mylist.removeFront ( )
    mylist.removeRear()
    assert mylist.toList() == []
testDoublyLinkedList2()
testDoublyLinkedList3()
# Out:
# Cannot remove 93
