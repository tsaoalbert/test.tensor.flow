# %% [markdown]
# <h1> <a href= "http://interactivepython.org/runestone/static/pythonds/Recursion/toctree.html"> HW #4:  Recursion </a>  </h1>
# <ul>
#
# <li> Recursion vs Iteration </li>
# <li> Three Laws of Recusion</li>
# <li>  Example: Tower of Hanoi, Maze, Dynamic Programming</li>
# </ul>

# %% [markdown]
# <h3> <a href= "http://interactivepython.org/runestone/static/pythonds/Recursion/pythondsProgrammingExercises.html
#     ">4.17. Programming Exercises</a> </h3>

# %% [raw]
# Q#1:
# Write both recursive and iterative function to compute the factorial of a number.
# How does the performance of the recursive function compare to that of an iterative version?
#    F(0)=F(1) = 1
#    F(n) = F(n-1)*n, for n >=2

# %%
import time
def  fac_r (n):
    if (n<=1):
        return 1
    return fac_r(n-1)*n

def fac_i(n):
    ans = 1
    for i in range (1,n+1):
        ans *= i
    return ans
n=20
start = time.time()
x = fac_i(n)
end = time.time()
ti = end-start

start = time.time()
y = fac_r(n)
end = time.time()
tr = end-start
print ( "iterative = ", x, ti )
print ( "recursive = ", y,tr )
# Out:
# iterative =  2432902008176640000 4.506111145019531e-05
# recursive =  2432902008176640000 4.410743713378906e-05

# %% [raw]
# Q#2
# Write both  recursive and iterative function to compute the Fibonacci sequence.
# How does the performance of the recursive function compare to that of an iterative version?
#            F(1)=F(2) = 1
#    F(n) = F(n-1)+F(n-2), for n >= 3

# %%
def fib_r (n):
    if (n <=2):
        return 1
    return fib_r(n-1) + fib_r(n-2)
    
def fib_i ( n):
    a=b=c=1
    for i in range (3,n+1):
        c = a+b;
        a,b = b, c
    return c
    
n=30
start = time.time()
x = fib_i(n)
end = time.time()
ti = end-start

start = time.time()
y = fib_r(n)
end = time.time()
tr = end-start
print ( "iterative = ", x, ti )
print ( "recursive = ", y,tr )
# Out:
# iterative =  832040 8.606910705566406e-05
# recursive =  832040 0.3293037414550781

# %%
# recursive
def fib_recursive (n): # (2^n)
    if n <=0:
        return 0
    elif n<=2:
        return n
    else:
        return fib_recursive(n-1)+fib_recursive(n-2)
# iterative
def fib_iterative (n): # O(n)
    a=b=1
    for i in range (2, n+1):
        c = a+b
        a = b
        b = c
    return c

for i in range (10,20, 2):
    x = fib_recursive(i)
    y = fib_iterative(i)
    assert x==y

# %%
import timeit
import random as r
import string

oa = timeit.Timer("fib_recursive(n)", "from __main__ import fib_recursive,n")
ob = timeit.Timer("fib_iterative(n)", "from __main__ import fib_iterative,n ")

s = "{0:>8s}: {1:^15s} {2:^15s}".format("n", "fib_recursive", "fib_iterative")

print (s)
num_repeats = 1       # 100000
m = 1
X= list ( range ( 30, 37, 2))
A=[]; B=[]; 
for n in X :
    a = oa.timeit(number=num_repeats)
    b = ob.timeit(number=num_repeats)
    A.append ( a )
    B.append ( b )
    
    s = "{0:>8d}: {1:^15.5f} {2:^15.5f}".format(n,a,b)
    print (s)
# Out:
#        n:  fib_recursive   fib_iterative
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-2cd33a3e8b0b> in <module>
#      14 A=[]; B=[];
#      15 for n in X :
# ---> 16     a = oa.timeit(number=num_repeats)
#      17     b = ob.timeit(number=num_repeats)
#      18     A.append ( a )
#
# ~/anaconda3/lib/python3.7/timeit.py in timeit(self, number)
#     174         gc.disable()
#     175         try:
# --> 176             timing = self.inner(it, self.timer)
#     177         finally:
#     178             if gcold:
#
# ~/anaconda3/lib/python3.7/timeit.py in inner(_it, _timer)
#
# ImportError: cannot import name 'fib_recursive' from '__main__' (unknown location)

# %% [markdown]
# Q#3: Modify the <a href= "http://interactivepython.org/runestone/static/pythonds/Recursion/pythondsintro-VisualizingRecursion.html    ">  recursive tree program </a>
#   to produce a more realistic looking tree with various brnach length/thickness, and braching angles.
#
# * Modify the thickness of the branches so that as the branchLen gets smaller, the line gets thinner.
# * Modify the color of the branches so that as the branchLen gets very short it is colored like a leaf.
# * Modify the angle used in turning the turtle so that at each branch point the angle is selected at random in some range. For example choose the angle between 15 and 45 degrees. Play around to see what looks good.
# * Modify the branchLen recursively so that instead of always subtracting the same amount you subtract a random amount in some range.
# If you implement all of the above ideas you will have a very realistic looking tree.

# %%
import random as r

import turtle
# from http://interactivepython.org/runestone/static/pythonds/Recursion/pythondsintro-VisualizingRecursion.html
def tree(branchLen,t):
    if branchLen > 5:
        t.forward(branchLen)
        t.right(20)
        d = r.randint (12,15)  # a random number between 0 and 3

        tree(branchLen-d,t)
        t.left(40)
        tree(branchLen-d,t)
        t.right(20)
        t.backward(branchLen)

def main():
    t = turtle.Turtle()
    myWin = turtle.Screen()
    t.left(90)
    t.up()
    t.backward(100)
    t.down()
    t.color("green")
    tree(75,t)
    myWin.exitonclick()

main()

# %%
# answer Q#3
import turtle
import random as r

def tree(branchLen,t, thickness):
    if branchLen > 5:
        t.pensize(thickness)
        d = r.randint (0,3)  # a random number between 0 and 3
        b = branchLen-15-d   # branch lenth with some randomness
        if thickness > 2:
            thickness -= 2
        t.forward( b )
        t.right(20)
        tree(b,t, thickness)
        t.left(40)
        tree(b,t,thickness)
        t.right(20)
        t.backward( b )

def main():
    t = turtle.Turtle()
    myWin = turtle.Screen()
    t.left(90)
    t.up()
    n=200
    t.backward(n)
    t.down()
    t.color("green")
    tree(n*3//4,t, 10)
    myWin.exitonclick()

main()

# %% [markdown]
# Q#4<br/>
# Using the recursive rules as described, draw a  <a href= "hhttp://interactivepython.org/runestone/static/pythonds/Recursion/pythondsSierpinskiTriangle.html"> Sierpinski triangle </a> using paper and pencil.

# %%
import turtle

def drawTriangle(points,color,myTurtle):
    myTurtle.fillcolor(color)
    myTurtle.up()
    myTurtle.goto(points[0][0],points[0][1])
    myTurtle.down()
    myTurtle.begin_fill()
    myTurtle.goto(points[1][0],points[1][1])
    myTurtle.goto(points[2][0],points[2][1])
    myTurtle.goto(points[0][0],points[0][1])
    myTurtle.end_fill()

def getMid(p1,p2):
    return ( (p1[0]+p2[0]) / 2, (p1[1] + p2[1]) / 2)

def sierpinski(points,degree,myTurtle):
    colormap = ['blue','red','green','white','yellow',
                'violet','orange']
    drawTriangle(points,colormap[degree],myTurtle)
    if degree > 0:
        sierpinski([points[0],
                        getMid(points[0], points[1]),
                        getMid(points[0], points[2])],
                   degree-1, myTurtle)
        sierpinski([points[1],
                        getMid(points[0], points[1]),
                        getMid(points[1], points[2])],
                   degree-1, myTurtle)
        sierpinski([points[2],
                        getMid(points[2], points[1]),
                        getMid(points[0], points[2])],
                   degree-1, myTurtle)

def main():
   myTurtle = turtle.Turtle()
   myWin = turtle.Screen()
   myPoints = [[-100,-50],[0,100],[100,-50]]
   sierpinski(myPoints,3,myTurtle)
   myWin.exitonclick()

main()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-f7bbab5c3120> in <module>
#      40    myWin.exitonclick()
#      41
# ---> 42 main()
#
# <ipython-input-1-f7bbab5c3120> in main()
#      37    myWin = turtle.Screen()
#      38    myPoints = [[-100,-50],[0,100],[100,-50]]
# ---> 39    sierpinski(myPoints,3,myTurtle)
#      40    myWin.exitonclick()
#      41
#
# <ipython-input-1-f7bbab5c3120> in sierpinski(points, degree, myTurtle)
#      27                         getMid(points[0], points[1]),
#      28                         getMid(points[1], points[2])],
# ---> 29                    degree-1, myTurtle)
#      30         sierpinski([points[2],
#      31                         getMid(points[2], points[1]),
#
# <ipython-input-1-f7bbab5c3120> in sierpinski(points, degree, myTurtle)
#      18     colormap = ['blue','red','green','white','yellow',
# ...

# %% [raw]
# Q#5
# Draw a call stack for the Tower of Hanoi problem. Assume that you start with a stack of three disks.
# The following are the first 2 of total 7 steps.
#                                      0    .    .
#                                      1    .    .
#                                      2    .    .
#                                    ---------------
#                                      A    B    C
#
# Step 1: Move disc 0 from A to C
#                                      .    .    .
#                                      1    .    .
#                                      2    .    0
#                                    ---------------
#                                      A    B    C
#
# Step 2: Move disc 1 from A to B
#                                      .    .    .
#                                      .    .    .
#                                      2    1    0
#                                    ---------------
#                                      A    B    C

# %%
class Stack:
    def __init__(self):
        self.items = []
    
    def copy(self,y):
        self.items = y.items.copy()
                
    def __getitem__(self,i):
        return self.items[i]
    
    def isEmpty(self):
        return self.items == []

    def __str__(self):
      return str ( self.items )

    def push(self, item):
        self.items.append(item)

    def pop(self):
        return self.items.pop()

    def peek(self):
        return self.items[len(self.items)-1]

    def size(self):
        return len(self.items)

# %%
def layer(A,i):
    if i < A.size():
        return "{0:^5d}".format (A[i])
    else:
        return "{0:^5s}".format (".")
def printStep (steps,A,B,C,x ):
        names = "ABC"
        print ("Step", steps, end="")
        print (": Move disc", x,  "from", names[A], "to", names[C] )   
        
def printStack (arr,A,B,C,m ):
    offset = " "*35
    for i in range (m-1,-1,-1):
        s=offset
        for x in arr:
            s += layer(x,i)
        print (s)
    print (offset + "-"*15)
    s = offset
    for i in "ABC":
        s += "{0:^5s}".format(i)  
    print (s)
    print ()

def tower (n, arr, A,B,C, steps,m):
    if n > 0:
        steps = tower (n-1,arr,A,C,B, steps,m )
        x = arr[A].pop()
        arr[C].push ( x )
        printStep (steps,A,B,C,x )
        printStack(arr,A,B,C,m)
        steps += 1
        steps = tower (n-1,arr, B,A,C, steps,m)
    return steps
def hanoi(n):
    arr=[]
    for i in range(3):
        arr.append(Stack() )
    for i in range (n):
        arr[0].push(n-1-i)
    A=0
    B=1
    C=2
    printStack(arr,A,B,C,n)
    tower (n, arr, A,B,C, 1, n )
hanoi(3)
# Out:
#                                      0    .    .
#                                      1    .    .
#                                      2    .    .
#                                    ---------------
#                                      A    B    C
#
# Step 1: Move disc 0 from A to C
#                                      .    .    .
#                                      1    .    .
#                                      2    .    0
#                                    ---------------
#                                      A    B    C
#
# Step 2: Move disc 1 from A to B
#                                      .    .    .
#                                      .    .    .
#                                      2    1    0
#                                    ---------------
#                                      A    B    C
#
# Step 3: Move disc 0 from C to B
#                                      .    .    .
#                                      .    0    .
# ...
